# %%
import os
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('kota.jpg')
#cv2.imshow("mage" , img)
gray = cv2.imread('kota.jpg', cv2.IMREAD_GRAYSCALE)
#cv2.imshow("imagegray" , gray)
#plt.imshow(img)
newImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(newImg)
plt.plot()
print(img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[[  7   8   6]
#   [  7   8   6]
#   [  7   8   6]
#   ...
#   [231 227 226]
#   [236 231 228]
#   [238 233 230]]
#
#  [[  7   8   6]
#   [  7   8   6]
#   [  7   8   6]
#   ...
#   [232 228 227]
#   [236 231 228]
#   [239 234 231]]
#
#  [[  7   8   6]
#   [  7   8   6]
#   [  7   8   6]
#   ...
#   [233 229 228]
#   [237 232 229]
#   [239 234 231]]
#
#  ...
#
#  [[ 16  18  19]
#   [ 16  18  19]
#   [ 16  18  19]
#   ...
#   [ 63  79 122]
#   [ 64  79 125]
#   [ 64  79 125]]
#
#  [[ 16  18  19]
#   [ 16  18  19]
#   [ 16  18  19]
#   ...
#   [ 59  75 118]
#   [ 60  75 121]
#   [ 60  75 121]]
#
#  [[ 16  18  19]
#   [ 16  18  19]
#   [ 16  18  19]
#   ...
#   [ 59  72 116]
#   [ 59  72 118]
#   [ 60  73 119]]]
